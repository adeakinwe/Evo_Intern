# %% [markdown]
# Import Web Scrapping Libraries

# %%
from bs4 import BeautifulSoup as bs
import requests as req

# %% [markdown]
# Scrapping Website

# %%
url = 'https://ackodrive.com/cars/?sortBy=price-high-low'

# %%
res = req.get(url)

# %%
html_content = bs(res.text, 'html.parser')

# %%
print(html_content.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    New Cars in India 2024 - Buy Cars Online - Home Delivery
#   </title>
#   <meta content="New Cars in India 2024 - Buy Cars Online - Home Delivery" name="title"/>
#   <meta content="Buy Cars online in India. Shop for New Cars and get Doorstep delivery ✓ Guaranteed Lowest Price on New Car Purchase ✓ Amazing Offers." name="description"/>
#   <meta content="en_US" name="og:locale"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://ackodrive.com/cars/" rel="canonical"/>
#   <meta content="https://ackodrive.com/" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="AckoDrive" property="og:site_name"/>
#   <meta content="New Cars in India 2024 - Buy Cars Online - Home Delivery" property="og:title"/>
#   <meta content="Buy Cars online in India. Shop for New Cars and get Doorstep delivery ✓ Guaranteed Lowest Price on New Car Purchase ✓ Amazing Offers." property="og:description"/>
#   <meta content="https://ackodrive.com/_next/static/images/lpBannerNew1Mob-622db7eaffe2cf332bf7ef3f2057cb15.png.webp" property="og:image"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="400" property="og:image:height"/>
#   <meta content="2597379697174105" property="fb:app_id"/>
#   <meta content="686444421716619" property="fb:page_id"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="https://ackodrive.com/cars/" property="twitter:url"/>
#   <meta content="New Cars in India 2024 - Buy Cars Online - Home Delivery" property="twitter:title"/>
#   <meta content="Buy Cars online in India. Shop for New Cars and get Doorstep delivery ✓ Guaranteed Lowest Price on New Car Purchase ✓ Amazing Offers." property="twitter:description"/>
#   <meta content="https://ackodrive.com/_next/static/images/lpBannerNew1Mob-622db7eaffe2cf332bf7ef3f2057cb15.png.webp" property="twitter:image"/>
#   <meta content="New Cars in India 2024 - Buy Cars Online - Home Delivery" property="twitter:image:alt"/>
#   <meta content="23" name="next-head-count"/>
#   <meta charset="utf-8"/>
#   <meta content="8lms8etsgjf72fa5szlrzn6btxkjzc" name="facebook-domain-verification"/>
#   <meta content="E9fzijhcVdiR5bmi_j_8eZ2sdJFW0B4gb1amqcNzSSw" name="google-site-verification"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://ackodrive-assets.s3.amazonaws.com" rel="preconnect"/>
#   <link href="https://drive.ackoassets.com" rel="preconnect"/>
#   <link as="style" href="/assets/critical.css" rel="preload"/>
#   <link href="/assets/critical.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/1317.460919e3ea237cf5.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/5605.1d80d8a106be9578.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/9667-e3fdff64476dc684.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/5860-be7585fab72ae714.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/5906-97433902a4ad0337.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/5261.8574d78da177a987.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/1663.1556fd82ea597c5f.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/193.2510a1737ea52706.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8058.c8aa208060486b5a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/2690.ebe08df745555bb3.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/5675-3d97ec8cfecda3ad.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/9886-9aceebb7c6cb6efc.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8786.57c5019700aa769c.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/2234.4154730cbd746e42.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8447-da8e3494c38b5b9e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/4278-5178620b86b63d19.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/1532.7bbd13e55b3f0e39.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8612.906a19f56aea3b3e.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8548.7d378a06c6ac41d7.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/7190.0734e0ad7cf3dc33.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/2815.4bdccadc2561cd76.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/7478.321939e87d3fa2c9.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-b8611bc139243e03.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework-4476b420910bf56f.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-4951d79819abd4a8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/_app-1bb332f70e9eb20a.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/2264-27775bd364a5c8ff.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/2028-173cb4611f682d29.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/8467-32b9626785bb08c9.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/pages/cars-787c07b7186d9c0a.js">
#   </script>
#   <script defer="" src="/_next/static/IQRw1EVTmXKc-LrfTDE6P/_buildManifest.js">
#   </script>
#   <script defer="" src="/_next/static/IQRw1EVTmXKc-LrfTDE6P/_ssgManifest.js">
#   </script>
#   <style id="__jsx-bab53a6364520493">
#    @font-face{font-family:"Inter";font-style:normal;font-weight:100;font-display:swap;src:url("/assets/fonts/Inter-Thin.woff2")format(url("woff2")),url("/assets/fonts/Inter-Thin.woff")format(url("woff"));src:url("/assets/fonts/Inter-Thin.woff2")format("woff2"),url("/assets/fonts/Inter-Thin.woff")format("woff")}@font-face{font-family:"Inter";font-style:italic;font-weight:100;font-display:swap;src:url("/assets/fonts/Inter-ThinItalic.woff2")format(url("woff2")),url("/assets/fonts/Inter-ThinItalic.woff")format(url("woff"));src:url("/assets/fonts/Inter-ThinItalic.woff2")format("woff2"),url("/assets/fonts/Inter-ThinItalic.woff")format("woff")}@font-face{font-family:"Inter";font-style:normal;font-weight:200;font-display:swap;src:url("/assets/fonts/Inter-ExtraLight.woff2")format(url("woff2")),url("/assets/fonts/Inter-ExtraLight.woff")format(url("woff"));src:url("/assets/fonts/Inter-ExtraLight.woff2")format("woff2"),url("/assets/fonts/Inter-ExtraLight.woff")format("woff")}@font-face{font-family:"Inter";font-style:italic;font-weight:200;font-display:swap;src:url("/assets/fonts/Inter-ExtraLightItalic.woff2")format(url("woff2")),url("/assets/fonts/Inter-ExtraLightItalic.woff")format(url("woff"));src:url("/assets/fonts/Inter-ExtraLightItalic.woff2")format("woff2"),url("/assets/fonts/Inter-ExtraLightItalic.woff")format("woff")}@font-face{font-family:"Inter";font-style:normal;font-weight:300;font-display:swap;src:url("/assets/fonts/Inter-Light.woff2")format(url("woff2")),url("/assets/fonts/Inter-Light.woff")format(url("woff"));src:url("/assets/fonts/Inter-Light.woff2")format("woff2"),url("/assets/fonts/Inter-Light.woff")format("woff")}@font-face{font-family:"Inter";font-style:italic;font-weight:300;font-display:swap;src:url("/assets/fonts/Inter-LightItalic.woff2")format(url("woff2")),url("/assets/fonts/Inter-LightItalic.woff")format(url("woff"));src:url("/assets/fonts/Inter-LightItalic.woff2")format("woff2"),url("/assets/fonts/Inter-LightItalic.woff")format("woff")}@font-face{font-family:"Inter";font-style:normal;font-weight:400;font-display:swap;src:url("/assets/fonts/Inter-Regular.woff2")format(url("woff2")),url("/assets/fonts/Inter-Regular.woff")format(url("woff"));src:url("/assets/fonts/Inter-Regular.woff2")format("woff2"),url("/assets/fonts/Inter-Regular.woff")format("woff")}@font-face{font-family:"Inter";font-style:italic;font-weight:400;font-display:swap;src:url("/assets/fonts/Inter-Italic.woff2")format(url("woff2")),url("/assets/fonts/Inter-Italic.woff")format(url("woff"));src:url("/assets/fonts/Inter-Italic.woff2")format("woff2"),url("/assets/fonts/Inter-Italic.woff")format("woff")}@font-face{font-family:"Inter";font-style:normal;font-weight:500;font-display:swap;src:url("/assets/fonts/Inter-Medium.woff2")format(url("woff2")),url("/assets/fonts/Inter-Medium.woff")format(url("woff"));src:url("/assets/fonts/Inter-Medium.woff2")format("woff2"),url("/assets/fonts/Inter-Medium.woff")format("woff")}@font-face{font-family:"Inter";font-style:italic;font-weight:500;font-display:swap;src:url("/assets/fonts/Inter-MediumItalic.woff2")format(url("woff2")),url("/assets/fonts/Inter-MediumItalic.woff")format(url("woff"));src:url("/assets/fonts/Inter-MediumItalic.woff2")format("woff2"),url("/assets/fonts/Inter-MediumItalic.woff")format("woff")}@font-face{font-family:"Inter";font-style:normal;font-weight:600;font-display:swap;src:url("/assets/fonts/Inter-SemiBold.woff2")format(url("woff2")),url("/assets/fonts/Inter-SemiBold.woff")format(url("woff"));src:url("/assets/fonts/Inter-SemiBold.woff2")format("woff2"),url("/assets/fonts/Inter-SemiBold.woff")format("woff")}@font-face{font-family:"Inter";font-style:italic;font-weight:600;font-display:swap;src:url("/assets/fonts/Inter-SemiBoldItalic.woff2")format(url("woff2")),url("/assets/fonts/Inter-SemiBoldItalic.woff")format(url("woff"));src:url("/assets/fonts/Inter-SemiBoldItalic.woff2")format("woff2"),url("/assets/fonts/Inter-SemiBoldItalic.woff")format("woff")}@font-face{font-family:"Inter";font-style:nor ...
#   </style>
#   <style id="jss-server-side">
#    html {
#   box-sizing: border-box;
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
# *, *::before, *::after {
#   box-sizing: inherit;
# }
# strong, b {
#   font-weight: 700;
# }
# body {
#   color: rgba(0, 0, 0, 0.87);
#   margin: 0;
#   font-size: 0.875rem;
#   font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#   font-weight: 400;
#   line-height: 1.43;
#   letter-spacing: 0.01071em;
#   background-color: #fafafa;
# }
# @media print {
#   body {
#     background-color: #fff;
#   }
# }
#   body::backdrop {
#     background-color: #fafafa;
#   }
#   </style>
#   <style data-styled="fIipCn dcWJDZ bAZswF lnwZKh kHXfpE bFMmVL etUVW dHjRqZ kChvil dWyaEs bVeuKC dhRWSz fHqFXE PFGEs fXIDop gWjRWN biASdV gfMkyq gKxdZa jnezrF fMbbNL jBYSOk gDXjcX jzShwz eJekxL eghPCN juZxgi eXvAhp jinBBz degBPI oBDXG fenZaR ekzjkN gexSDE jwCMhT eIRCkq goAajg gSSEHm jSIPv dBOdoa jGYjUd cKfNKW GmTDd lbMxqM eWBalw bubJpu cTaCzc cAEvSE eyQJGs kcQAQj kWljuL OJHUk eiGELX kUUmWD fMgIaI jtAUjc RBuIa cXLacK cPNPID LQrbf iwKFyQ gMrtmi bMwutE jvhnwy gtEVRu kgMVVv dNVZBr gNfUZW ffoMBG kEjWdw haSBAh fuepeG bsOgLr xkcbA bjjqra bApIql fsEKEh jtSQKj hMWMUZ gxZUsP cQxDwz fmbNgS ahdBh jYfKjZ hUUWuJ hZsrFc bADLOh dQNhKz dDbXKV eofXRk dngYSw GicJj gyzSoN fyShGq gabbBU ekUhiB hkFXPQ kUafRm eFMssg jAxAVN kelhYn QwMOx EZQIk cdfhGY epomYJ iifefc lMFkn hoCAxG fLEAcc JTsVX eXsJng gDROZA hjGkan gxXFOV bAcEMw jKGFVQ lkBjDm cvXgWE ixfQDI fmfRPb cuyyWz cxpiFL gJdgWz ikwFnN hJgdla MVqVj lezrkV ejfWBh fUHrei dPeXSO budxLF bmZWPJ kHRWiX glpvRh dHkYya fQqzDM ejcXAa dWaoEb fFevvb lhXIXl btbaoV fSKIzd cgxhIp itVgMs ilJOAm dvkaim eQZIHs gDnOFi ddKWRI ezUSlZ jUDrWM eRJAES ihDFBO krkoaM cLqgnV iBecZH bIXoGN dbJncH ebBlxv hJdxZK aOigA bKuwyJ kHdXQg IcPMr gwnREU jLueQl iegVxx gwkVcG jONuaT JSYg lofZwO cWKKhT eiFNin fFyrT fbFJMI kGitOs" data-styled-version="4.4.1">
#    /* sc-component-id: styles__Wrapper-sc-35e229d9-0 */
# .dcWJDZ{position:relative;padding-bottom:30px;background-color:#ffffff;} .dcWJDZ #item0{padding:40px 0 0 0;border-top:10px solid #f1f3f8;} .dcWJDZ #item1{border-top:10px solid #f1f3f8;} @media (max-width:700px){.dcWJDZ{width:100%;}}
# /* sc-component-id: styles__ListingWrapper-sc-35e229d9-3 */
# .eghPCN{background:#F3F2F8;padding:32px 20px;border-top:none;} @media (min-width:1200px){.eghPCN{padding-left:100px;padding-right:100px;}}
# /* sc-component-id: styles__CarsCollectionWrapper-sc-35e229d9-4 */
# .juZxgi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:15px;padding-bottom:22px;}
# /* sc-component-id: styles__CarsCollectionTitle-sc-35e229d9-5 */
# .eXvAhp{font-family:"Inter";font-style:normal;font-weight:600;font-size:18px;line-height:24px;color:#040222;padding-bottom:10px;}
# /* sc-component-id: styles__Wrapper-sc-6d9e3f57-0 */
# .eRJAES > div:last-child{padding:0 0 60px 0;} @media (max-width:700px){.eRJAES > div:last-child{padding:0 0 20px 0;}}
# /* sc-component-id: styles__Wrapper-sc-f41e9e23-0 */
# .bAZswF{padding:10px 100px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:4.5rem;z-index:101;position:-webkit-sticky;position:sticky;top:0;background:#fff;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;box-shadow:none;}
# /* sc-component-id: styles__CitySearchProfileWrapper-sc-f41e9e23-3 */
# .dhRWSz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;gap:22px;}
# /* sc-component-id: styles__MenuLogoHeaderWrapper-sc-f41e9e23-4 */
# .lnwZKh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-flex-shrink:1;-ms-flex-negative:1;flex-shrink:1;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:66px;}
# /* sc-component-id: styles__HeaderSection-sc-dccd5557-0 */
# .cAEvSE{font-family:"Inter";font-style:normal;padding:0px 24px;background-color:#FFFFFF;box-shadow:0px 4px 6px -2px rgba(54,53,76,0.08);border-bottom:3px solid #E7E7F0;border-radius:12px 12px 0px 0px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: styles__TotalCars-sc-dccd5557-1 */
# .eyQJGs{font-weight:600;padding:16px 0px;font-size:18px;color:#040222;}
# /* sc-component-id: styles__CarListWrapper-sc-dccd5557-2 */
# .fMgIaI{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;background-color:#ffffff;padding:1.5rem;-webkit-column-gap:1.5rem;column-gap:1.5rem;row-gap:1.5rem;}
# /* sc-component-id: styles__PaginationWrapper-sc-dccd5557-3 */
# .jUDrWM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;padding:20px 0;background-color:#ffffff;border-radius:0 0 12px 12px;} .jUDrWM .pagination{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:10px;margin:0;list-style-type:none;background:#fff;} .jUDrWM .pagination > li{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:30px;padding:10px;border:1px solid #dfe3e8;border-radius:4px;color:#000;cursor:pointer;background:#fff;font-weight:bold;margin:0 10px;} .jUDrWM .pagination > li.disabled > a{cursor:default;} .jUDrWM .pagination > li > a{color:#000;-webkit-text-decoration:none;text-decoration:none;font-size:14px;} .jUDrWM .pagination > li.active{background:#fff;border:1px solid #5e27c9;pointer-events:none;} .jUDrWM .pagination > li.active > a{color:#5e27c9;pointer-events:none;} .jUDrWM .pagination > li.disabled{background:#eee;cursor:default;}
# /* sc-component-id: styles__DesktopContainerWithFilter-sc-dccd5557-6 */
# .jinBBz{display:grid;grid-template-columns:minmax(auto,16rem) auto;gap:0.75rem;}
# /* sc-component-id: styles__FiltersWrapper-sc-dccd5557-7 */
# .degBPI{-webkit-flex:1 0 15rem;-ms-flex:1 0 15rem;flex:1 0 15rem;}
# /* sc-component-id: styles__RightPanelWrapper-sc-dccd5557-8 */
# .cTaCzc{-webkit-flex:3 1 auto;-ms-flex:3 1 auto;flex:3 1 auto;}
# /* sc-component-id: styles__SortGroup-sc-dccd5557-9 */
# .kcQAQj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: styles__SortItemWrapper-sc-dccd5557-10 */
# .kWljuL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 16px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}
# /* sc-component-id: styles__SortItem-sc-dccd5557-11 */
# .OJHUk{font-family:"Inter";font-style:normal;font-weight:400;font-size:14px;color:#5b5675;background:#ffffff;text-align:center;cursor:pointer;border:none;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;padding:0;}.eiGELX{font-family:"Inter";font-style:normal;font-weight:400;font-size:14px;color:#5b5675;background:#ffffff;text-align:center;cursor:pointer;border:none;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;padding:0;font-weight:500;font-size:14px;color:#040222;margin-top:4px;}
# /* sc-component-id: styles__BorderBottom-sc-dccd5557-12 */
# .kUUmWD{width:100%;height:4px;background-color:#0fa457;border-radius:4px;}
# /* sc-component-id: styles__StyledFilterIcon-sc-ef98852-0 */
# .ekzjkN{width:100%;max-width:24px;}
# /* sc-component-id: styles__StyledDownArrow-sc-ef98852-2 */
# .GmTDd{width:1.5rem;cursor:pointer;justify-self:end;margin-left:auto;}
# /* sc-component-id: styles__ApplyButton-sc-ef98852-4 */
# .bubJpu{padding:0.75rem 0.5rem;width:100%;border:none;font-family:"Inter";font-style:normal;font-weight:600;font-size:0.875rem;line-height:0.875rem;color:#ffffff;background:#e0e0e8;border-radius:8px;}
# /* sc-component-id: styles__ClearButton-sc-ef98852-5 */
# .eWBalw{padding:0.75rem 0.5rem;width:100%;border:none;font-family:"Inter";font-style:normal;font-weight:600;font-size:0.875rem;line-height:0.875rem;color:#1b73e8;background:none;cursor:pointer;color:#040222;cursor:auto;opacity:0.3;}
# /* sc-component-id: FilterContent__ExpressDeliveryIconWrapper-sc-78a0902f-0 */
# .jSIPv{width:18px !important;height:24px;margin-left:25px !important;display:block !important;} .jSIPv path:first-child{stroke:#4f34d2;} .jSIPv path:last-child{fill:#4f34d2;}
# /* sc-component-id: FilterContent__HotDealIconWrapper-sc-78a0902f-1 */
# .goAajg{width:18px !important;height:24px;margin-left:25px !important;display:block !important;} .goAajg path:first-child{stroke:#f58700;} .goAajg path:last-child{fill:#f58700;}
# /* sc-component-id: FilterContent__FilterContentWrapper-sc-78a0902f-4 */
# .jwCMhT{margin-left:1.25rem;margin-top:1.5rem;}
# /* sc-component-id: FilterContent__CheckboxContainer-sc-78a0902f-7 */
# .eIRCkq{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;cursor:pointer;font-family:"Inter";font-style:normal;font-weight:400;font-size:0.875rem;line-height:1.5rem;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;} .eIRCkq input{position:absolute;opacity:0;cursor:pointer;height:0;width:0;} .eIRCkq span{border:1px solid #a9a5be;border-radius:4px;width:1rem;min-width:1rem;height:1rem;margin-right:0.625rem;} @media screen and (max-width:700px){.eIRCkq span{width:1.25rem;min-width:1.25rem;height:1.25rem;}} .eIRCkq:hover input:unchecked ~ span{background-color:#0fa457;opacity:0.1;} .eIRCkq input:checked ~ span{background:#0fa457;border:none;} .eIRCkq input:indeterminate ~ span{border:1px solid #0fa457;} .eIRCkq svg{position:absolute;display:none;} .eIRCkq input:checked ~ svg{display:block;} .eIRCkq input:indeterminate ~ svg{display:block;} .eIRCkq svg{left:0.25rem;width:0.5rem;} @media screen and (max-width:700px){.eIRCkq svg{left:0.3125rem;width:0.625rem;}}
# /* sc-component-id: FilterContent__BoldLabelWrapper-sc-78a0902f-8 */
# .gSSEHm{font-family:"Inter";font-style:normal;font-weight:600;font-size:0.875rem;line-height:1.5rem;color:#040222;margin-left:25px;}
# /* sc-component-id: FilterTitle__FilterTitleWrapper-sc-7bf879f2-0 */
# .dBOdoa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:1.5rem;cursor:pointer;}
# /* sc-component-id: FilterTitle__FitlersAppliedCount-sc-7bf879f2-1 */
# .jGYjUd{font-family:"Inter";font-style:normal;font-weight:500;font-size:0.75rem;line-height:1rem;color:#7c47e1;margin-right:0.375rem;min-width:1rem;text-align:right;}
# /* sc-component-id: FilterTitle__FilterTitleName-sc-7bf879f2-2 */
# .cKfNKW{font-family:"Inter";font-style:normal;font-weight:600;font-size:0.875rem;line-height:1.5rem;color:#040222;}
# /* sc-component-id: FiltersDesktop__FiltersMain-sc-3f101d9d-0 */
# .gexSDE{max-height:calc(100vh - 16rem);overflow-y:auto;padding-bottom:1rem;box-shadow:none;}
# /* sc-component-id: FiltersDesktop__FiltersWrapper-sc-3f101d9d-1 */
# .oBDXG{background:#fff;border-radius:12px;position:-webkit-sticky;position:sticky;top:80px;padding:16px;}
# /* sc-component-id: FiltersDesktop__FiltersHeader-sc-3f101d9d-2 */
# .fenZaR{font-family:"Inter";font-style:normal;font-weight:600;font-size:1.125rem;line-height:1.5rem;color:#040222;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:4px;border-bottom:1px solid #e7e7f0;padding-bottom:0.875rem;}
# /* sc-component-id: FiltersDesktop__FiltersFooter-sc-3f101d9d-3 */
# .lbMxqM{font-family:"Inter";font-style:normal;font-weight:600;font-size:1.125rem;line-height:1.5rem;color:#040222;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;gap:4px;border-top:1px solid #e7e7f0;padding-top:1.125rem;}
# /* sc-component-id: styles__Wrapper-sc-d4192e15-0 */
# .fHqFXE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;position:relative;height:-webkit-fit-content;height:-moz-fit-content;height:fit-content;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}
# /* sc-component-id: styles__IconWrapper-sc-d4192e15-1 */
# .PFGEs{width:1.5rem;height:1.5rem;padding:0.1875rem 0.2125rem 0.25rem 0.2125rem;}
# /* sc-component-id: styles__DownArrowWrapper-sc-d4192e15-2 */
# .gWjRWN{height:24px;padding-top:0.5px;margin-left:4px;}
# /* sc-component-id: styles__TextWrapper-sc-d4192e15-3 */
# .fXIDop{color:#040222;font-family:Inter;font-size:0.75rem;font-style:normal;font-weight:400;line-height:normal;font-size:1rem;}
# /* sc-component-id: styles__Wrapper-sc-2ea3b845-0 */
# .bFMmVL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:2.4375rem;}
# /* sc-component-id: styles__MenuOptionWrapper-sc-85184f30-0 */
# .etUVW{color:#000;}
# /* sc-component-id: styles__Title-sc-85184f30-2 */
# .kChvil{cursor:pointer;-webkit-text-decoration:none;text-decoration:none;} .kChvil:hover{color:#0b753e;}
# /* sc-component-id: styles__ActiveLine-sc-85184f30-3 */
# .dWyaEs{color:#5b5675;}.bVeuKC{color:#5b5675;color:#000;border-bottom:0.1875rem solid #0FA457;}
# /* sc-component-id: styles__MenuOption-sc-85184f30-4 */
# .dHjRqZ{font-size:1.125rem;font-weight:600;}
# /* sc-component-id: styles__ModelDetails-sc-57d31ed8-0 */
# .cXLacK{font-family:"Inter";padding:16px 16px 5px 16px;position:relative;min-height:90px;}
# /* sc-component-id: styles__ModelTitle-sc-57d31ed8-4 */
# .LQrbf{font-size:18px;font-weight:700;margin-bottom:4px;margin-top:6px;line-height:19px;max-width:75%;}
# /* sc-component-id: styles__Make-sc-57d31ed8-5 */
# .iwKFyQ{color:#282e33;}
# /* sc-component-id: styles__ModelName-sc-57d31ed8-6 */
# .gMrtmi{color:#5b5675;}
# /* sc-component-id: styles__ModelInfo-sc-57d31ed8-8 */
# .bMwutE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-weight:400;font-size:12px;line-height:12px;color:#36354c;}
# /* sc-component-id: styles__Dot-sc-57d31ed8-9 */
# .gtEVRu{width:3px;height:3px;background:#36354c;border-radius:50%;margin-left:6px;margin-right:6px;}
# /* sc-component-id: styles__VariantTitle-sc-57d31ed8-10 */
# .haSBAh{font-family:"Inter";font-style:normal;font-weight:500;font-size:16px;line-height:17px;color:#040222;margin-bottom:5px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: styles__VariantInfo-sc-57d31ed8-12 */
# .fuepeG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-weight:400;font-size:12px;line-height:12px;color:#36354c;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;font-family:"Inter";}
# /* sc-component-id: styles__VariantColors-sc-57d31ed8-13 */
# .bsOgLr{padding-top:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}
# /* sc-component-id: styles__VariantColor-sc-57d31ed8-14 */
# .xkcbA{width:16px;height:16px;background:#e5e4e2;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #ccc;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.bjjqra{width:16px;height:16px;background:linear-gradient(135deg,#e5e4e2 0%,#e5e4e2 50%,#181919 50%,#181919 100%) no-repeat;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #ccc;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.bApIql{width:16px;height:16px;background:#4b545b;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #dedede;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.fsEKEh{width:16px;height:16px;background:#cdd6d8;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #ccc;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.jtSQKj{width:16px;height:16px;background:#141510;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #dedede;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.hMWMUZ{width:16px;height:16px;background:#614c41;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #dedede;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.gxZUsP{width:16px;height:16px;background:linear-gradient(135deg,#363a39 0%,#363a39 50%,#0f110c 50%,#0f110c 100%) no-repeat;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #dedede;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.cQxDwz{width:16px;height:16px;background:linear-gradient(135deg,#a5a2a5 0%,#a5a2a5 50%,#0f110c 50%,#0f110c 100%) no-repeat;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #ccc;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.fmbNgS{width:16px;height:16px;background:linear-gradient(135deg,#26312b 0%,#26312b 50%,#0f110c 50%,#0f110c 100%) no-repeat;border-radius:50%;margin-right:7px;margin-bottom:10px;border:1px solid #dedede;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.ahdBh{width:16px;height:16px;background:linear-gradient(135deg,#611829 0%,#611829 50%,#0f110c 50%,#0f110c 100%) no-repeat;border-radius:50%;margin-right ...
# /* sc-component-id: styles__VariantPrice-sc-57d31ed8-15 */
# .dWaoEb{position:relative;margin-top:auto;}
# /* sc-component-id: styles__PriceLabel-sc-57d31ed8-16 */
# .fFevvb{font-family:"Inter";font-style:normal;font-weight:400;font-size:12px;line-height:15px;color:#282e33;margin-bottom:4px;}
# /* sc-component-id: styles__CityName-sc-57d31ed8-17 */
# .lhXIXl{font-family:"Inter";font-style:normal;font-weight:400;font-size:12px;line-height:15px;color:#5b5675;}
# /* sc-component-id: styles__Price-sc-57d31ed8-18 */
# .btbaoV{font-family:"Inter";font-style:normal;font-weight:700;font-size:18px;line-height:120%;color:#282e33;margin-bottom:2px;}
# /* sc-component-id: styles__Ribbon-sc-57d31ed8-22 */
# .fSKIzd{--f:10px;width:128px;height:55px;position:absolute;inset:0 calc(-1 * var(--f) - 1rem) auto auto;padding:6px 12px 6px 12px;-webkit-clip-path:polygon( 0 0, 100% 0, 100% calc(100% - var(--f)), calc(100% - var(--f)) 100%, calc(100% - var(--f)) calc(100% - var(--f)), 0 calc(100% - var(--f)) );clip-path:polygon( 0 0, 100% 0, 100% calc(100% - var(--f)), calc(100% - var(--f)) 100%, calc(100% - var(--f)) calc(100% - var(--f)), 0 calc(100% - var(--f)) );background:linear-gradient( 92.61deg, #ddd4c6 -37.28%, #ffffff 73.07%, #ddd4c6 101.08% );border:1px solid #eae4dc;box-shadow:0 -9px 0 0 inset #b9b6b2;border-radius:10px 10px 0px 0px;margin-top:"5px";}
# /* sc-component-id: styles__ExpressDeliveryRibbon-sc-57d31ed8-23 */
# .ddKWRI{--f:10px;width:128px;height:55px;position:absolute;inset:0 calc(-1 * var(--f) - 1rem) auto auto;padding:6px 12px 6px 12px;-webkit-clip-path:polygon( 0 0, 100% 0, 100% calc(100% - var(--f)), calc(100% - var(--f)) 100%, calc(100% - var(--f)) calc(100% - var(--f)), 0 calc(100% - var(--f)) );clip-path:polygon( 0 0, 100% 0, 100% calc(100% - var(--f)), calc(100% - var(--f)) 100%, calc(100% - var(--f)) calc(100% - var(--f)), 0 calc(100% - var(--f)) );background:linear-gradient( 92.61deg, #ddd4c6 -37.28%, #ffffff 73.07%, #ddd4c6 101.08% );border:1px solid #eae4dc;box-shadow:0 -9px 0 0 inset #b9b6b2;border-radius:10px 10px 0px 0px;margin-top:"5px";cursor:pointer;padding:5px 8px 15px 8px;background:linear-gradient( 93.19deg, #d9c8fb -18.27%, #f1eef5 68.55%, #d9c8fb 99.51% );border:1px solid #dccbfc;box-shadow:0 -9px 0 0 inset #b191ed;}
# /* sc-component-id: styles__DeliveredBy-sc-57d31ed8-27 */
# .cgxhIp{font-family:"Inter";font-style:normal;font-weight:400;font-size:10px;line-height:11px;text-align:center;color:#040222;margin-bottom:4px;}
# /* sc-component-id: styles__ExpressDeliveryText-sc-57d31ed8-28 */
# .ezUSlZ{font-family:"Inter";font-style:normal;font-weight:400;font-size:10px;line-height:12px;text-align:center;color:#040222;border-bottom:1px dashed #9893b4;box-sizing:border-box;margin:2px 12px;height:12px;}
# /* sc-component-id: styles__DateText-sc-57d31ed8-30 */
# .itVgMs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:5px;font-family:"Inter";font-style:normal;font-weight:600;font-size:12px;line-height:13px;color:#040222;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;}.ilJOAm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:5px;font-family:"Inter";font-style:normal;font-weight:600;font-size:12px;line-height:13px;color:#040222;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;gap:2px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:15px;}
# /* sc-component-id: styles__AnchorTagWithoutUnderline-sc-57d31ed8-32 */
# .cPNPID{-webkit-text-decoration:none;text-decoration:none;display:contents;color:inherit;}
# /* sc-component-id: styles__ParaWithoutMargins-sc-57d31ed8-33 */
# .jvhnwy{margin:0;}
# /* sc-component-id: styles__Wrapper-sc-cbcba852-0 */
# .jtAUjc{-webkit-flex:1 0 18.125rem;-ms-flex:1 0 18.125rem;flex:1 0 18.125rem;border:1px solid #d9d9e1;background:linear-gradient(180deg,#fafafa 0%,#ffffff 43.01%);border-radius:12px;max-width:18.125rem;min-width:18.125rem;min-height:461px;border-radius:12px;}
# /* sc-component-id: styles__ModelSection-sc-cbcba852-1 */
# .RBuIa{min-height:217px;padding-bottom:14px;min-height:246px;}
# /* sc-component-id: styles__ImageWrapper-sc-cbcba852-2 */
# .kgMVVv{width:100%;height:120px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
# /* sc-component-id: styles__Actions-sc-cbcba852-3 */
# .dNVZBr{margin:6px 12px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;line-height:12px;}
# /* sc-component-id: styles__Action-sc-cbcba852-4 */
# .gNfUZW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;cursor:pointer;margin-left:auto;}
# /* sc-component-id: styles__ActionText-sc-cbcba852-5 */
# .ffoMBG{margin:0 4px;font-size:10px;color:#1b73e8;font-family:"Inter";font-style:normal;font-weight:500;}
# /* sc-component-id: styles__DesktopVariantDetails-sc-cbcba852-9 */
# .kEjWdw{padding:0 1rem 0.75rem 1rem;border-top:1px solid #f0f0f6;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;min-height:190px;padding-top:1.125rem;}
# /* sc-component-id: styles__CTAWrapper-sc-cbcba852-10 */
# .dvkaim{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;text-align:center;margin:0 16px 16px;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}
# /* sc-component-id: styles__CTA-sc-cbcba852-11 */
# .gDnOFi{font-family:"Inter";font-style:normal;font-weight:600;font-size:14px;line-height:16px;-webkit-text-decoration:none;text-decoration:none;color:#040222;background:#040222;border-radius:8px;color:#FFFFFF;padding:12px 12px;margin-left:7px;width:100%;height:48px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
# /* sc-component-id: styles__LoginCTA-sc-cbcba852-12 */
# .eQZIHs{border:1px solid #5b5675;border-radius:8px;font-family:"Inter";font-style:normal;font-weight:500;font-size:13px;line-height:15px;text-align:center;color:#36354c;padding:4px 10px;-webkit-text-decoration:none;text-decoration:none;margin-right:7px;width:100%;height:48px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} .eQZIHs > div{font-size:12px;color:#0c8c4a;margin-top:2px;font-weight:600;}
# /* sc-component-id: styles__LoginSignupCTAWrapper-sc-70e651de-0 */
# .jzShwz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:-webkit-min-content;height:-moz-min-content;height:min-content;cursor:pointer;}
# /* sc-component-id: styles__LoginSignupCTAText-sc-70e651de-1 */
# .eJekxL{margin-left:0.188rem;padding-top:0.125rem;}
# /* sc-component-id: InputsV2__Wrapper-sc-6e2fa73b-0 */
# .gfMkyq{width:100%;margin:0;} @media (max-width:700px){.gfMkyq{max-width:100%;}}
# /* sc-component-id: InputsV2__InputBox-sc-6e2fa73b-1 */
# .gKxdZa{display:grid;grid-template-columns:30px 1fr 30px;border:1px solid #e7e7f0;box-sizing:border-box;border-radius:8px;height:48px;padding:0 2px;} @media (max-width:700px){}
# /* sc-component-id: InputsV2__InputWrapper-sc-6e2fa73b-2 */
# .jBYSOk{position:relative;height:100%;}
# /* sc-component-id: InputsV2__InputComponent-sc-6e2fa73b-3 */
# .gDXjcX{width:100%;height:100%;outline:0;border:none;padding-left:5px;font-family:"Inter";font-size:16px;font-weight:400;} .gDXjcX::-webkit-inner-spin-button,.gDXjcX::-webkit-outer-spin-button{-webkit-appearance:none;}
# /* sc-component-id: InputsV2__IconWrapper-sc-6e2fa73b-4 */
# .jnezrF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# /* sc-component-id: InputsV2__Icon-sc-6e2fa73b-6 */
# .fMbbNL{height:20px;width:20px;cursor:default;}
# /* sc-component-id: search__SearchInputWrapper-sc-26800e65-0 */
# .biASdV{width:18.125rem;position:relative;background-color:#ffffff;}
# /* sc-component-id: styles__Wrapper-sc-17cff016-0 */
# .ihDFBO{background:#fff;padding:0 0 50px 0;} @media (max-width:700px){.ihDFBO{width:100%;padding:0 0 30px 0;}}
# /* sc-component-id: styles__Heading-sc-17cff016-1 */
# .krkoaM{font-weight:800;font-size:26px;text-align:center;-webkit-letter-spacing:0.02em;-moz-letter-spacing:0.02em;-ms-letter-spacing:0.02em;letter-spacing:0.02em;color:#414a53;padding:40px 0 40px 0;} @media (max-width:700px){.krkoaM{padding:20px 0;font-size:16px;}}
# /* sc-component-id: styles__Container-sc-17cff016-2 */
# .cLqgnV{display:grid;grid-template-columns:1fr 1fr 1fr;grid-gap:20px;width:1200px;margin:0 auto;} @media (max-width:700px){.cLqgnV{display:block;width:100%;padding:0 0 40px 0;}.cLqgnV > div:not(:last-child){margin:20px auto 100px auto;}.cLqgnV > div:nth-child(1){margin-top:0;}}
# /* sc-component-id: styles__ItemWrapper-sc-17cff016-3 */
# .iBecZH{width:330px;height:350px;margin:0 auto;position:relative;} @media (max-width:700px){.iBecZH{margin:20px auto;width:100%;}}
# /* sc-component-id: styles__ReviewerImageWrapper-sc-17cff016-4 */
# .bIXoGN{height:280px;width:330px;border-radius:10px;overflow:hidden;position:relative;} @media (max-width:700px){.bIXoGN{width:100%;border-radius:0;}}
# /* sc-component-id: styles__StarImage-sc-17cff016-5 */
# .ebBlxv{height:15px;width:15px;position:relative;margin:0 2px 0 0;display:inline-block;}
# /* sc-component-id: styles__ContentWrapper-sc-17cff016-6 */
# .dbJncH{position:absolute;bottom:0;background:#fff;border-radius:5px;width:90%;left:0;right:0;margin:auto;padding:15px;box-shadow:0px 3.5748px 26.811px rgba(0,0,0,0.05);} .dbJncH::before{content:"";position:absolute;top:-6px;left:20px;height:12px;width:12px;background:#fff;-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);} @media (max-width:700px){.dbJncH{margin:90px auto 0 auto;bottom:-50px;}}
# /* sc-component-id: styles__Review-sc-17cff016-7 */
# .hJdxZK{font-weight:bold;font-size:12px;line-height:19px;color:#000000;border-bottom:1px solid #eee;padding-bottom:10px;}
# /* sc-component-id: styles__CustomerName-sc-17cff016-8 */
# .aOigA{font-weight:bold;font-size:12px;line-height:17px;color:#151619;margin:10px 0 0 0;}
# /* sc-component-id: styles__City-sc-17cff016-9 */
# .bKuwyJ{font-size:10px;line-height:17px;color:#555a68;}
# /* sc-component-id: styles__Address-sc-b1e1b85d-2 */
# .gwkVcG{font-size:12px;line-height:18px;color:#414a53;width:265px;margin:20px 0 0 0;}
# /* sc-component-id: styles__ADNewLogo-sc-b1e1b85d-3 */
# .iegVxx{width:100px;height:46px;object-fit:scale-down;}
# /* sc-component-id: styles__Wrapper-sc-b19b57ab-0 */
# .jONuaT{margin:20px 0 0 0;}
# /* sc-component-id: styles__Title-sc-b19b57ab-1 */
# .JSYg{font-weight:600;font-size:12px;color:#414a53;} @media (max-width:700px){.JSYg{font-size:18px;font-weight:bold;}}
# /* sc-component-id: styles__SocialIconsWrapper-sc-b19b57ab-2 */
# .lofZwO{display:grid;grid-template-columns:repeat(5,40px);grid-gap:10px;margin:15px 0;}
# /* sc-component-id: styles__SocialIcon-sc-b19b57ab-3 */
# .cWKKhT{height:30px;width:30px;position:relative;cursor:pointer;}
# /* sc-component-id: styles__Wrapper-sc-dedc81a1-0 */
# .kHdXQg{background:#fff;border-top:10px solid #fafafa;padding:40px 20px;}
# /* sc-component-id: styles__Container-sc-dedc81a1-1 */
# .IcPMr{display:grid;grid-template-columns:1fr 1fr 1fr;grid-gap:20px;width:1100px;margin:0 auto;} @media (max-width:700px){.IcPMr{width:100%;display:block;}}
# /* sc-component-id: styles__CompanyDetails-sc-dedc81a1-2 */
# .gwnREU{border-right:1px solid #eee;}
# /* sc-component-id: styles__LinksWrapper-sc-dedc81a1-3 */
# .eiFNin{border-right:1px solid #eee;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;} .eiFNin:last-child{border:none;} @media (max-width:700px){.eiFNin{-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;}}
# /* sc-component-id: styles__ItemWrapper-sc-dedc81a1-5 */
# .fFyrT{display:grid;grid-template-rows:repeat(3,1fr);}
# /* sc-component-id: styles__Title-sc-dedc81a1-6 */
# .fbFJMI{font-weight:bold;font-size:14px;color:#414a53;margin:5px 0 5px 0;text-transform:capitalize;} @media (max-width:700px){.fbFJMI{margin:15px 0 5px 0;}}
# /* sc-component-id: styles__Link-sc-dedc81a1-7 */
# .kGitOs{font-size:12px;color:#434f5a;margin:10px 0;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}
# /* sc-component-id: styles__ADNewLogo-sc-ec655cd3-0 */
# .kHXfpE{display:block;-webkit-text-decoration:none;text-decoration:none;width:5rem;height:2.5rem;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin:0.5rem 0 0;cursor:pointer;position:relative;}
# /* sc-component-id: sc-global-1833038205 */
# @font-face{font-family:'Inter';font-style:normal;font-weight:400;src:url(https://fonts.gstatic.com/s/inter/v11/UcCO3FwrK3iLTeHuS_fvQtMwCp50KnMw2boKoduKmMEVuLyfAZ9hjp-Ek-_EeA.woff) format('woff');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD;}
#   </style>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div class="_app__ComponentWrapper-sc-4125c6b8-0 fIipCn">
#     <div class="styles__Wrapper-sc-35e229d9-0 dcWJDZ">
#      <div class="styles__Wrapper-sc-f41e9e23-0 bAZswF">
#       <div class="styles__MenuLogoHeaderWrapper-sc-f41e9e23-4 lnwZKh">
#        <a class="styles__ADNewLogo-sc-ec655cd3-0 kHXfpE" href="https://ackodrive.com/">
#         <svg fill="none" viewbox="0 0 71 33" xmlns="http://www.w3.org/2000/svg">
#          <path d="M46.974 0 23.726.047c-3.02.01-5.46 2.432-5.46 5.419.01 2.986 2.393 5.343 5.411 5.333l23.248-.046c3.02-.01 5.527-2.367 5.517-5.353.01-2.987-2.45-5.41-5.47-5.4h.002Z" fill="#7C47E1">
#          </path>
#          <path d="M46.78 9.43c-2.252 0-4.085-1.804-4.085-4.02 0-2.218 1.823-4.038 4.065-4.038 2.241 0 4.084 1.803 4.084 4.02 0 2.217-1.813 4.028-4.065 4.038Z" fill="#fff">
#          </path>
#          <path d="M49.478 6.012c.345-1.48-.588-2.957-2.085-3.3-1.497-.343-2.991.58-3.337 2.06-.345 1.48.588 2.957 2.085 3.3 1.497.343 2.991-.58 3.337-2.06Z" fill="#37C87E">
#          </path>
#          <path d="M28.015 5.43c0-2.218-1.832-4.021-4.083-4.021-2.252 0-4.065 1.813-4.065 4.037 0 2.225 1.833 4.02 4.084 4.02a4.094 4.094 0 0 0 2.764-1.08v.422a.65.65 0 0 0 .654.646c.36 0 .654-.291.654-.646l-.01-3.249v-.132l.002.002Zm-4.064 2.74c-1.519 0-2.763-1.22-2.773-2.724 0-1.501 1.235-2.731 2.754-2.741 1.519 0 2.763 1.22 2.773 2.724.01 1.512-1.235 2.742-2.754 2.742ZM32.986 9.447c-2.261 0-4.104-1.813-4.111-4.047 0-2.235 1.832-4.057 4.094-4.067 1.017 0 1.984.365 2.744 1.034a.647.647 0 0 1 .046.92.656.656 0 0 1-.93.047 2.828 2.828 0 0 0-1.863-.703c-1.538 0-2.783 1.24-2.783 2.761 0 1.522 1.255 2.751 2.793 2.751.693 0 1.348-.252 1.862-.712a.666.666 0 0 1 .931.046.65.65 0 0 1-.047.921 4.041 4.041 0 0 1-2.734 1.051l-.002-.002ZM42.76 8.256l-3.533-2.92 3.523-2.874a.648.648 0 0 0 .085-.912.665.665 0 0 0-.92-.083l-3.818 3.136V1.974a.65.65 0 0 0-.654-.647.652.652 0 0 0-.654.647l.01 6.789a.65.65 0 0 0 .654.647c.36 0 .654-.292.654-.647l-.01-2.639 3.827 3.126a.661.661 0 0 0 .921-.086.63.63 0 0 0-.086-.91v.002Z" fill="#fff">
#          </path>
#          <path d="M33.206 21.924c.59-3.572-1.541-5.7-5.275-5.7h-7.24l-2.785 16.774h4.555l.926-5.537h1.572l2.024 5.537h4.947l-2.367-6.257c1.925-.86 3.268-2.49 3.645-4.817h-.002Zm-4.75 0c-.23 1.44-1.28 2-2.884 2h-1.597l.519-3.102-4.219-.965h5.326v.005h.66c1.572 0 2.422.622 2.195 2.065v-.003Z" fill="url(#ackodrive-new-logo_svg__a)">
#          </path>
#          <path d="M10.998 16.223H0l4.535 1.04L2.56 29.155l4.73-1.082 1.331-7.982h1.688c2.622 0 3.834.884 3.276 4.292-.59 3.604-2.325 4.75-4.817 4.75H7.114v-.007l-4.556.044-.635 3.83h6.551c5.11 0 8.746-3.014 9.599-8.159.884-5.34-1.901-8.616-7.075-8.616v-.003Z" fill="url(#ackodrive-new-logo_svg__b)">
#          </path>
# ...
#              </stop>
#              <stop offset="0.83" stop-color="#154E31">
#              </stop>
#              <stop offset="0.91" stop-color="#092215">
#              </stop>
#              <stop offset="0.97">
#              </stop>
#             </lineargradient>
#             <lineargradient gradientunits="userSpaceOnUse" id="ackodrive-new-logo_svg__d" x1="32.252" x2="39.589" y1="24.609" y2="24.609">
#              <stop offset="0.2" stop-color="#37C87E">
#              </stop>
#              <stop offset="0.34" stop-color="#36C47B">
#              </stop>
#              <stop offset="0.45" stop-color="#33BA75">
#              </stop>
#              <stop offset="0.56" stop-color="#2EA86A">
#              </stop>
#              <stop offset="0.66" stop-color="#27905A">
#              </stop>
#              <stop offset="0.76" stop-color="#1E7046">
#              </stop>
#              <stop offset="0.86" stop-color="#14492E">
#              </stop>
#              <stop offset="0.95" stop-color="#071B11">
#              </stop>
#              <stop offset="1">
#              </stop>
#             </lineargradient>
#             <lineargradient gradientunits="userSpaceOnUse" id="ackodrive-new-logo_svg__e" x1="40.633" x2="57.929" y1="24.609" y2="24.609">
#              <stop offset="0.2" stop-color="#37C87E">
#              </stop>
#              <stop offset="0.33" stop-color="#36C47B">
#              </stop>
#              <stop offset="0.44" stop-color="#33BA75">
#              </stop>
#              <stop offset="0.54" stop-color="#2EA86A">
#              </stop>
#              <stop offset="0.64" stop-color="#27905B">
#              </stop>
#              <stop offset="0.73" stop-color="#1F7047">
#              </stop>
#              <stop offset="0.82" stop-color="#144A2E">
#              </stop>
#              <stop offset="0.91" stop-color="#081D12">
#              </stop>
#              <stop offset="0.96">
#              </stop>
#             </lineargradient>
#            </defs>
#           </svg>
#          </div>
#          <div class="styles__Address-sc-b1e1b85d-2 gwkVcG">
#           36/5, Hustlehub One East, Somasandrapalya, 27th Main Rd, Sector 2, HSR Layout, Bengaluru, Karnataka 560102.
#          </div>
#         </div>
#         <div class="styles__Wrapper-sc-b19b57ab-0 jONuaT">
#          <div class="styles__Title-sc-b19b57ab-1 JSYg">
#           We’re Socially Active
#          </div>
#          <div class="styles__SocialIconsWrapper-sc-b19b57ab-2 lofZwO">
#           <a href="https://www.facebook.com/ackodrive/" rel="noopener noreferrer" target="_blank">
#            <div class="styles__SocialIcon-sc-b19b57ab-3 cWKKhT">
#             <span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0">
#              <img alt="Facebook" data-nimg="fill" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down"/>
#              <noscript>
#               <img alt="Facebook" data-nimg="fill" decoding="async" loading="lazy" sizes="100vw" src="/_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=3840&amp;q=75" srcset="/_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=640&amp;q=75 640w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=750&amp;q=75 750w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=828&amp;q=75 828w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=1080&amp;q=75 1080w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=1200&amp;q=75 1200w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=1920&amp;q=75 1920w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=2048&amp;q=75 2048w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialFacebook-bd092590af887efa65922929310526c5.png&amp;w=3840&amp;q=75 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down"/>
#              </noscript>
#             </span>
#            </div>
#           </a>
#           <a href="https://www.instagram.com/ackodrive/" rel="noopener noreferrer" target="_blank">
#            <div class="styles__SocialIcon-sc-b19b57ab-3 cWKKhT">
#             <span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0">
#              <img alt="Instagram" data-nimg="fill" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down"/>
#              <noscript>
#               <img alt="Instagram" data-nimg="fill" decoding="async" loading="lazy" sizes="100vw" src="/_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=3840&amp;q=75" srcset="/_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=640&amp;q=75 640w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=750&amp;q=75 750w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=828&amp;q=75 828w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=1080&amp;q=75 1080w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=1200&amp;q=75 1200w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=1920&amp;q=75 1920w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=2048&amp;q=75 2048w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialInstagram-3d343fa15e5848f6ad7bdbf4cd08a401.png&amp;w=3840&amp;q=75 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down"/>
#              </noscript>
#             </span>
#            </div>
#           </a>
#           <a href="https://twitter.com/ackodrive" rel="noopener noreferrer" target="_blank">
#            <div class="styles__SocialIcon-sc-b19b57ab-3 cWKKhT">
#             <span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0">
#              <img alt="Twitter" data-nimg="fill" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down"/>
#              <noscript>
#               <img alt="Twitter" data-nimg="fill" decoding="async" loading="lazy" sizes="100vw" src="/_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=3840&amp;q=75" srcset="/_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=640&amp;q=75 640w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=750&amp;q=75 750w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=828&amp;q=75 828w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=1080&amp;q=75 1080w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=1200&amp;q=75 1200w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=1920&amp;q=75 1920w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=2048&amp;q=75 2048w, /_next/image/?url=%2F_next%2Fstatic%2Fimages%2FsocialTwitter-94e2baeeec2b96e6687a9e2491f92d47.png&amp;w=3840&amp;q=75 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down"/>
#              </noscript>
#             </span>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="styles__LinksWrapper-sc-dedc81a1-3 eiFNin">
#         <div class="styles__ItemWrapper-sc-dedc81a1-5 fFyrT">
#          <div class="styles__Title-sc-dedc81a1-6 fbFJMI">
#           Company
#          </div>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://ackodrive.com/about-us/" target="_blank">
#           About Us
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://ackodrive.com/best-price-offer/" target="_blank">
#           Price Offer
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://ackodrive.com/contact-us/" target="_blank">
#           Contact Us
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/" target="_blank">
#           Group company
#          </a>
#         </div>
#        </div>
#        <div class="styles__LinksWrapper-sc-dedc81a1-3 eiFNin">
#         <div class="styles__ItemWrapper-sc-dedc81a1-5 fFyrT">
#          <div class="styles__Title-sc-dedc81a1-6 fbFJMI">
#           Legal
#          </div>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://ackodrive.com/privacy-policy/" target="_blank">
#           Privacy Policy
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://ackodrive.com/terms-and-conditions/" target="_blank">
#           Terms &amp; Conditions
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/car-insurance/" target="_blank">
#           Car Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/two-wheeler-insurance/" target="_blank">
#           Bike Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/health-insurance/ " target="_blank">
#           Health Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/life-insurance/" target="_blank">
#           Life Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/life-insurance/term-insurance/" target="_blank">
#           Term Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/group-health-insurance/" target="_blank">
#           Group Health Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/travel-insurance/" target="_blank">
#           Travel Insurance
#          </a>
#          <a class="styles__Link-sc-dedc81a1-7 kGitOs" href="https://www.acko.com/visa/ " target="_blank">
#           Visa
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"pathname":"/cars","isMobile":false,"isRobot":false,"carsData":{"success":true,"total_count":84,"total_pages":6,"items_per_page":16,"current_page_number":1,"has_next":"http://workspace.ackodrive.com/workspace/master/v2/cars/?page=2","has_previous":null,"total_mmvc_count":5867,"total_mmv_count":1096,"has_hot_deal":true,"result":[{"brand_id":1,"model_id":1208,"brand_name":"Toyota","model_name":"Fortuner","model_slug":"toyota-fortuner","hero_image":"https://ackodrive-assets.s3.amazonaws.com/media/test_DjPAYpq.png","basic_feature":{"body_type":"SUV","seat":"7 Seater"},"trust_markers":[{"is_new_launch":false}],"hot_deal":false,"variants":[{"variant_id":12819,"variant_name":"2.8 GR-S 4x4 AT","variant_slug":"toyota-fortuner-28-gr-s-4x4-at","basic_feature":{"fuel_type":"Diesel","engine":"2755 cc","transmission":"Automatic"},"colors":[{"color":{"brand_color":"Platinum White Pearl","base_colors":["White"],"hex_codes":["#e5e4e2"],"color_type":"NM"},"variant_color_id":21608,"price":null,"hot_deal":false,"hot_deal_difference":null}],"hot_deal":false,"price":{"adsp_price":6128609,"final_price":6128609,"market_price":"6128609.00","savings":"XXX202","waiting_period":"22 September 2024","deal_type":"ADSP"}},{"variant_id":12818,"variant_name":"2.8 4x4 AT","variant_slug":"toyota-fortuner-28-4x4-at","basic_feature":{"fuel_type":"Diesel","engine":"2755 cc","transmission":"Automatic"},"colors":[{"color":{"brand_color":"Platinum White Pearl","base_colors":["White"],"hex_codes":["#e5e4e2"],"color_type":"NM"},"variant_color_id":21601,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Silver Metallic","base_colors":["Silver"],"hex_codes":["#cdd3e0"],"color_type":"M"},"variant_color_id":21607,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Avant Garde Bronze","base_colors":["Bronze"],"hex_codes":["#beb2a6"],"color_type":"M"},"variant_color_id":21606,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Attitude Black","base_colors":["Black"],"hex_codes":["#181919"],"color_type":"M"},"variant_color_id":21605,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Super White","base_colors":["White"],"hex_codes":["#ffffff"],"color_type":"M"},"variant_color_id":21604,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Phantom Brown","base_colors":["Brown"],"hex_codes":["#4b4140"],"color_type":"M"},"variant_color_id":21603,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Sparkling Black Crystal Shine","base_colors":["Black"],"hex_codes":["#1c1d1f"],"color_type":"M"},"variant_color_id":21602,"price":null,"hot_deal":false,"hot_deal_difference":null}],"hot_deal":false,"price":{"adsp_price":5066691,"final_price":5066691,"market_price":"5066691.00","savings":"XXX787","waiting_period":"22 September 2024","deal_type":"ADSP"}},{"variant_id":12817,"variant_name":"2.8 4x4 MT","variant_slug":"toyota-fortuner-28-4x4-mt","basic_feature":{"fuel_type":"Diesel","engine":"2755 cc","transmission":"Manual"},"colors":[{"color":{"brand_color":"Platinum White Pearl","base_colors":["White"],"hex_codes":["#e5e4e2"],"color_type":"NM"},"variant_color_id":21594,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Silver Metallic","base_colors":["Silver"],"hex_codes":["#cdd3e0"],"color_type":"M"},"variant_color_id":21600,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Avant Garde Bronze","base_colors":["Bronze"],"hex_codes":["#beb2a6"],"color_type":"M"},"variant_color_id":21599,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Attitude Black","base_colors":["Black"],"hex_codes":["#181919"],"color_type":"M"},"variant_color_id":21598,"price":null,"hot_deal":false,"hot_deal_difference":null},{"color":{"brand_color":"Super White","base_colors":["White"],"hex_codes":["#ffffff"],"colo ...
#   </script>
#  </body>
# </html>

# %%
all_cars = html_content.find_all('div',{'data-testid':'listingcardesktop'})

# %%
print(len(all_cars))
# Out:
# 16

# %%
all_cars[0
# Out:
# <div class="styles__Wrapper-sc-cbcba852-0 jtAUjc" data-testid="listingcardesktop"><div class="styles__ModelSection-sc-cbcba852-1 RBuIa"><div class="styles__ModelDetails-sc-57d31ed8-0 cXLacK"><a class="styles__AnchorTagWithoutUnderline-sc-57d31ed8-32 cPNPID" data-testid="car_model_brand_title" href="https://ackodrive.com/cars/toyota-fortuner/"><h2 class="styles__ModelTitle-sc-57d31ed8-4 LQrbf"><span class="styles__Make-sc-57d31ed8-5 iwKFyQ">Toyota</span> <span class="styles__ModelName-sc-57d31ed8-6 gMrtmi">Fortuner</span></h2></a><div class="styles__ModelInfo-sc-57d31ed8-8 bMwutE"><p class="styles__ParaWithoutMargins-sc-57d31ed8-33 jvhnwy" data-testid="car_model_body_type">SUV</p><div class="styles__Dot-sc-57d31ed8-9 gtEVRu"></div><p class="styles__ParaWithoutMargins-sc-57d31ed8-33 jvhnwy" data-testid="car_model_seat">7 Seater</p><div class="styles__Dot-sc-57d31ed8-9 gtEVRu"></div><p class="styles__ParaWithoutMargins-sc-57d31ed8-33 jvhnwy" data-testid="car_model_variants">1/7 variants</p></div></div><a class="styles__AnchorTagWithoutUnderline-sc-57d31ed8-32 cPNPID" data-testid="car_image" href="https://ackodrive.com/cars/toyota-fortuner/"><div class="styles__ImageWrapper-sc-cbcba852-2 kgMVVv"><span style="box-sizing:border-box;display:block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:absolute;top:0;left:0;bottom:0;right:0"><img alt="Toyota Fortuner" data-nimg="fill" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down;object-position:center"/><noscript><img alt="Toyota Fortuner" data-nimg="fill" decoding="async" loading="lazy" sizes="100vw" src="/_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=3840&amp;q=75" srcset="/_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=640&amp;q=75 640w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=750&amp;q=75 750w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=828&amp;q=75 828w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=1080&amp;q=75 1080w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=1200&amp;q=75 1200w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=1920&amp;q=75 1920w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=2048&amp;q=75 2048w, /_next/image/?url=https%3A%2F%2Fackodrive-assets.s3.amazonaws.com%2Fmedia%2Ftest_DjPAYpq.png&amp;w=3840&amp;q=75 3840w" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%;object-fit:scale-down;object-position:center"/></noscript></span></div></a><div class="styles__Actions-sc-cbcba852-3 dNVZBr"><div class="styles__Action-sc-cbcba852-4 gNfUZW" data-testid="nextVariant"><span class="styles__ActionText-sc-cbcba852-5 ffoMBG">Next variant</span><svg fill="none" height="16" width="16" xmlns="http://www.w3.org/2000/svg"><path d="M6.715 12.314a.494.494 0 0 1-.7-.696l3.594-3.615-3.595-3.62a.494.494 0 0 1 .7-.696l3.587 3.611a1 1 0 0 1 0 1.41l-3.586 3.606Z" fill="#B3B3B9"></path></svg></div></div></div><div class="styles__VariantDetails-sc-57d31ed8-11 styles__DesktopVariantDetails-sc-cbcba852-9 kEjWdw"><a class="styles__AnchorTagWithoutUnderline-sc-57d31ed8-32 cPNPID" data-testid="listing-car-variant-title" href="https://ackodrive.com/cars/toyota-fortuner-28-gr-s-4x4-at/"><h4 class="styles__VariantTitle-sc-57d31ed8-10 haSBAh">2.8 GR-S 4x4 AT</h4></a>< ...

# %% [markdown]
# Car Name

# %%
all_cars[0].find('h2').get_text()
# Out:
# 'Toyota Fortuner'

# %% [markdown]
# Fuel Type Transmission and Number of Available Color

# %%
all_cars[0].find('div',{'class':'styles__VariantInfo-sc-57d31ed8-12 fuepeG'}).get_text()
# Out:
# 'DieselAutomaticAvailable in 1 color'

# %% [markdown]
# Price

# %%
all_cars[0].find('div',{'class':'styles__Price-sc-57d31ed8-18 btbaoV'}).get_text()[1:-2]
# Out:
# '61.29'

# %% [markdown]
# Location

# %%
all_cars[0].find('div',{'class':'styles__CityName-sc-57d31ed8-17 lhXIXl'}).get_text()[3:]
# Out:
# 'Delhi'

# %% [markdown]
# Looping through to access all Cars

# %%
car_name = []
fuel_transmission_color = []
price = []
location = []

for car in all_cars:
    try:
        car_name.append(car.find('h2').get_text())
    except:
        car_name.append("N/A")
    try:
        fuel_transmission_color.append(car.find('div',{'class':'styles__VariantInfo-sc-57d31ed8-12 fuepeG'}).get_text())
    except:
        fuel_transmission_color.append("N/A")
    try:
        price.append(car.find('div',{'class':'styles__Price-sc-57d31ed8-18 btbaoV'}).get_text())
    except:
        price.append("N/A")
    try:
        location.append(car.find('div',{'class':'styles__CityName-sc-57d31ed8-17 lhXIXl'}).get_text())
    except:
        location.append("N/A")
# Out:
# ['₹61.29 L', '₹56.79 L', '₹50.30 L', '₹47.69 L', '₹45.21 L', '₹44.82 L', '₹42.16 L', '₹39.58 L', '₹38.47 L', '₹32.95 L', '₹32.20 L', '₹31.15 L', '₹29.91 L', '₹27.20 L', '₹26.88 L', '₹26.21 L']

# %%
Creating DataFrame

# %%
import pandas as pd

# %%
data = {'car_name':car_name, 'fuel_transmission_color': fuel_transmission_color, 'price': price, 'location': location}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                     car_name                 fuel_transmission_color  \
# 0            Toyota Fortuner     DieselAutomaticAvailable in 1 color
# 1   Toyota Fortuner Legender     DieselAutomaticAvailable in 1 color
# 2                 MG Gloster    DieselAutomaticAvailable in 4 colors
# 3              Jeep Meridian    DieselAutomaticAvailable in 6 colors
# 4               Skoda Kodiaq    PetrolAutomaticAvailable in 4 colors
# 5        Citroen C5 Aircross    DieselAutomaticAvailable in 7 colors
# 6             Hyundai Tucson    DieselAutomaticAvailable in 7 colors
# 7          Volkswagen Tiguan    PetrolAutomaticAvailable in 7 colors
# 8               Jeep Compass    DieselAutomaticAvailable in 7 colors
# 9            Mahindra XUV700   DieselAutomaticAvailable in 12 colors
# 10               Tata Safari     DieselAutomaticAvailable in 1 color
# 11              Tata Harrier     DieselAutomaticAvailable in 1 color
# 12        Mahindra Scorpio-N    DieselAutomaticAvailable in 7 colors
# 13            MG Hector Plus        DieselManualAvailable in 1 color
# 14                  MG ZS EV  ElectricAutomaticAvailable in 4 colors
# 15                 MG Hector        DieselManualAvailable in 1 color
#
#        price  location
# 0   ₹61.29 L  in Delhi
# 1   ₹56.79 L  in Delhi
# 2   ₹50.30 L  in Delhi
# 3   ₹47.69 L  in Delhi
# 4   ₹45.21 L  in Delhi
# 5   ₹44.82 L  in Delhi
# 6   ₹42.16 L  in Delhi
# 7   ₹39.58 L  in Delhi
# 8   ₹38.47 L  in Delhi
# 9   ₹32.95 L  in Delhi
# 10  ₹32.20 L  in Delhi
# 11  ₹31.15 L  in Delhi
# 12  ₹29.91 L  in Delhi
# 13  ₹27.20 L  in Delhi
# 14  ₹26.88 L  in Delhi
# 15  ₹26.21 L  in Delhi

# %% [markdown]
# Feature Engineeering and Data Preprocessing

# %%
df['fuel'] = df['fuel_transmission_color'].str.extract(r'(Diesel|Petrol|Electric)')

df['transmission'] = df['fuel_transmission_color'].str.extract(r'(Automatic|Manual)')

df['colors'] = df['fuel_transmission_color'].str.extract(r'(\d+)').astype(int)

df['price'] = df['price'].replace({'₹': '', 'L':''}, regex=True)
df['location'] = df['location'].replace({'in ':''}, regex=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fuel_transmission_color'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 df['fuel'] = df['fuel_transmission_color'].str.extract(r'(Diesel|Petrol|Electric)')
#       3 df['transmission'] = df['fuel_transmission_color'].str.extract(r'(Automatic|Manual)')
#       5 df['colors'] = df['fuel_transmission_color'].str.extract(r'(\d+)').astype(int)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'fuel_transmission_color'

# %%
df
# Out:
#                     car_name                 fuel_transmission_color  price  \
# 0            Toyota Fortuner     DieselAutomaticAvailable in 1 color  61.29
# 1   Toyota Fortuner Legender     DieselAutomaticAvailable in 1 color  56.79
# 2                 MG Gloster    DieselAutomaticAvailable in 4 colors  50.30
# 3              Jeep Meridian    DieselAutomaticAvailable in 6 colors  47.69
# 4               Skoda Kodiaq    PetrolAutomaticAvailable in 4 colors  45.21
# 5        Citroen C5 Aircross    DieselAutomaticAvailable in 7 colors  44.82
# 6             Hyundai Tucson    DieselAutomaticAvailable in 7 colors  42.16
# 7          Volkswagen Tiguan    PetrolAutomaticAvailable in 7 colors  39.58
# 8               Jeep Compass    DieselAutomaticAvailable in 7 colors  38.47
# 9            Mahindra XUV700   DieselAutomaticAvailable in 12 colors  32.95
# 10               Tata Safari     DieselAutomaticAvailable in 1 color  32.20
# 11              Tata Harrier     DieselAutomaticAvailable in 1 color  31.15
# 12        Mahindra Scorpio-N    DieselAutomaticAvailable in 7 colors  29.91
# 13            MG Hector Plus        DieselManualAvailable in 1 color  27.20
# 14                  MG ZS EV  ElectricAutomaticAvailable in 4 colors  26.88
# 15                 MG Hector        DieselManualAvailable in 1 color  26.21
#
#    location      fuel transmission  colors
# 0     Delhi    Diesel    Automatic       1
# 1     Delhi    Diesel    Automatic       1
# 2     Delhi    Diesel    Automatic       4
# 3     Delhi    Diesel    Automatic       6
# 4     Delhi    Petrol    Automatic       4
# 5     Delhi    Diesel    Automatic       7
# 6     Delhi    Diesel    Automatic       7
# 7     Delhi    Petrol    Automatic       7
# 8     Delhi    Diesel    Automatic       7
# 9     Delhi    Diesel    Automatic      12
# 10    Delhi    Diesel    Automatic       1
# 11    Delhi    Diesel    Automatic       1
# 12    Delhi    Diesel    Automatic       7
# 13    Delhi    Diesel       Manual       1
# 14    Delhi  Electric    Automatic       4
# 15    Delhi    Diesel       Manual       1

# %%
df.drop(columns=['fuel_transmission_color'], inplace=True)

# %%
df['price'] = df['price'].astype(float)

# %%
df
# Out:
#                     car_name  price location      fuel transmission  colors
# 0            Toyota Fortuner  61.29    Delhi    Diesel    Automatic       1
# 1   Toyota Fortuner Legender  56.79    Delhi    Diesel    Automatic       1
# 2                 MG Gloster  50.30    Delhi    Diesel    Automatic       4
# 3              Jeep Meridian  47.69    Delhi    Diesel    Automatic       6
# 4               Skoda Kodiaq  45.21    Delhi    Petrol    Automatic       4
# 5        Citroen C5 Aircross  44.82    Delhi    Diesel    Automatic       7
# 6             Hyundai Tucson  42.16    Delhi    Diesel    Automatic       7
# 7          Volkswagen Tiguan  39.58    Delhi    Petrol    Automatic       7
# 8               Jeep Compass  38.47    Delhi    Diesel    Automatic       7
# 9            Mahindra XUV700  32.95    Delhi    Diesel    Automatic      12
# 10               Tata Safari  32.20    Delhi    Diesel    Automatic       1
# 11              Tata Harrier  31.15    Delhi    Diesel    Automatic       1
# 12        Mahindra Scorpio-N  29.91    Delhi    Diesel    Automatic       7
# 13            MG Hector Plus  27.20    Delhi    Diesel       Manual       1
# 14                  MG ZS EV  26.88    Delhi  Electric    Automatic       4
# 15                 MG Hector  26.21    Delhi    Diesel       Manual       1

# %%
Data Validation

# %%
df.dtypes
# Out:
# car_name         object
# price           float64
# location         object
# fuel             object
# transmission     object
# colors            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# car_name        0
# price           0
# location        0
# fuel            0
# transmission    0
# colors          0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# Saving Dataframe to CSV

# %%
df.to_csv('cp12_ackodrive_cars.csv', index=False)

# %%
df
